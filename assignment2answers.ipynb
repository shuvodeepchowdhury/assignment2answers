# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# ANS:- the two boolean data types are :-
#
#      1) True 2) False
#          values should start with a capital ‘T’ and a capital ‘F’ otherwise, the interpreter gives an error the tpe should use a keywrd known as 'bool'.
#
# 2. What are the three different types of Boolean operators?
#
# ANS:- Three different types of boolean operators are:
#                1) comparision operator- < , > , >= , <= etc.
#                2) Binary boolean operator-True and True, True and False , False and False etc.
#                3) NOT operator- suppose a=True then NOT a will be False
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
#  ANS:- truth table for OR operator:-
#                              output
#           True    True       True
#           True    False      True
#           False   True       True
#           False   False      False
#
#         truth table for AND operator:-
#                              output
#           True    True       True
#           True    False      False
#           False   True       False
#           False   False      False
#
#          truth table for NOT operator:-
#           NOT True = False
#           NOT False= True
#
# 4. What are the values of the following expressions?
# ANS :-  (5 > 4) and (3 == 5)         :- False
#         not (5 > 4)                  :- False
#         (5 > 4) or (3 == 5)          :- True
#         not ((5 > 4) or (3 == 5))    :- False
# (True and True) and (True == False)  :- False
#         (not False) or (not True)    :- True
#
#
# 5. What are the six comparison operators?
#
# ANS:- the six comparison operators are:-
#
#        1) == (double equalto)
#        2) <  (smaller than)
#        3) >  (greater than)
#        4) <= (smaller than or equalto)
#        5) >= (greater than or equalto)
#        6) != (NOT equalto)
#
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
# ANS:- The single equalto is used for assigning a value to variable. whereas a double equalto is used for comparing two values         with each other .
#          lets consider a condition that you have to compare two variable that they a equal or not then you use the if statement
#          than if(a==b):
#          on the other hand if you are given a condition to assign value 5 to variable 'a' than you write a=5.
#
# 7. Identify the three blocks in this code:
#
# ANS:-
#
# spam = 0
# if spam == 10:
# print('eggs')  ## this is the first code block
#
# if spam > 5:
# print('bacon') ##  this is the second code block
#
# else:          ##   the entire else condition is the 3rd code block
# print('ham')
# print('spam')
# print('spam')
#
#
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# ANS:-         spam = 0
#               if spam == 1:
#                   print('Hello')
#               if spam == 2:
#                   print('Howdy')
#               else:
#                   print('Greetings!')
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
# ANS:- I always prefer a break stetement while writing  loop problem.
#
# 10. How can you tell the difference between break and continue?
#
# ANS:- The break statement terminates the loop containing it. Control of the program flows to the statement immediately after the body of the loop.
#            If the break statement is inside a nested loop (loop inside another loop), the break statement will terminate the innermost loop.
#            on the otherhand,The continue statement is used to skip the rest of the code inside a loop for the current iteration only. Loop does not terminate but continues on with the next iteration.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
# ANS:- Here inside a for loop if range(10) is given that indicates the termination point of the loop is 10 it will automatically        start from the point 0
#       Here inside a for loop if range(0,10) is given that indicates the termination point of the loop is 10 but it will start executing the loop from 0 as given inside the range 0 is working as a starting point of the loop.
#       Here inside a for loop if range(0,10,1) is given that indicates the termination point of the loop is 10 it will start executing the loop from 0 as given inside the range 0 is working as a starting point of the loop and the 1 indicating the increment value of the loop that means it will be incremented 1 step.
#
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
# ANS:-     for i in range(1,11):          # it will print the numbers 1 to 10
#               print(i)
#
#
#            i = 1
#            while i <= 10:                # it will print numbers 1 to 10 using while loop
#                print(i)
#                i += 1
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
#
# ANS:- I will call it by      spam.bacon()
